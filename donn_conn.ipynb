# %%
#1ere étape : installation et importation des bibliothèques nécessaires
#!pip install lxml 
#!pip install requests
#!pip install beautifulsoup4

# %%
import requests 
from bs4 import BeautifulSoup
import csv 
from itertools import zip_longest

# %%
#2ème étape : enregistrer le lien via python dans une variable
result = requests.get('https://www.letudiant.fr/palmares/classement-lycees.html')

# %%
#3ème étape : aller dans result pour accéder au contenu du lien et l'enregistrer dans src
src = result.content
#print(src)

# %%
#4ème étape : manipuler src avec BS
soup= BeautifulSoup(src,"lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 9]><html class="ie"><![endif]--><!--[if gt IE 9]><!--><html lang="fr" prefix="og:http://ogp.me/ns#" xml:lang="fr" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Classement des lycées 2022 - Série Générale – Un palmarès de l’Etudiant</title>
# <meta content="Classement des lycées 2022 - Série Générale – Un palmarès de l’Etudiant" name="title"/>
# <meta content="Quels sont les meilleurs lycées de votre ville ou de votre région (académie) ? L’Etudiant vous dévoile le classement des lycées 2022-2023. - L'Etudiant" name="description"/>
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# ...

# %%
td=soup.find_all("td")
print(td)
# Out:
# [<td>  19.36 </td>, <td>  A </td>, <td>  A </td>, <td> <a class="c-link u-themed" data-layer-event="etuEventLab" data-layer-event-act="Clic résultat de recherche" data-layer-event-cat="Classements et annuaires" data-layer-event-lab="LYCEE BERNAT ETXEPARE (GENERAL ET TECHNO.)" href="/palmares/classement-lycees/fiche/lycee-bernat-etxepare-1316.html" title="LYCEE BERNAT ETXEPARE (GENERAL ET TECHNO.)">  LYCEE BERNAT ETXEPARE (GENERAL ET TECHNO.) </a> </td>, <td>  64 </td>, <td>  BAYONNE </td>, <td>  Privé </td>, <td>  100 </td>, <td>  100 </td>, <td>  94 </td>, <td>  19.12 </td>, <td>  A </td>, <td>  A </td>, <td> <a class="c-link u-themed" data-layer-event="etuEventLab" data-layer-event-act="Clic résultat de recherche" data-layer-event-cat="Classements et annuaires" data-layer-event-lab="LYCEE NORD ATLANTIQUE (GENERAL ET TECHNO.)" href="/palmares/classement-lycees/fiche/lycee-nord-atlantique-general-et-techno-2266.html" title="LYCEE NORD ATLANTIQUE (GENERAL ET TECHNO.)">  LYCEE NORD ATL
# ...
